# %% [markdown]
# # ------------------------   A few Python Packages ---------------------------------

# %% [markdown]
# # load Pandas (as Excel)
# # for more detailed information see:
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html

# %%
import pandas as pd
print('Loading from repository, Done!')
# Out:
# Loading from repository, Done!

# %% [markdown]
# # 'pd' has different attributes. One of them is "read_csv" that can read a csv file.

# %%
# Load your csv data:
pd_data= pd.read_csv('Height_Weight_org.csv')

print('loading data, Done!')
# Out:
# loading data, Done!

# %% [markdown]
# # The csv file was loaded into pd_data (choose any name you loke).

# %% [markdown]
# # Now, "pd_data" is a Pandas file, so it has the same attributes. So, we can perform many things with this load file.
#
# # In the following we show the table:

# %%
pd_data
# Out:
#          Height    Weight
# 0      65.78331  112.9925
# 1      71.51521  136.4873
# 2      69.39874  153.0269
# 3      68.21660  142.3354
# 4      67.78781  144.2971
# ...         ...       ...
# 24995  69.50215  118.0312
# 24996  64.54826  120.1932
# 24997  64.69855  118.2655
# 24998  67.52918  132.2682
# 24999  68.87761  124.8742
#
# [25000 rows x 2 columns]

# %% [markdown]
# # head(n=5)
# # Return the first n rows.
#
# # This function returns the first n rows for the object based on position. It is useful for quickly testing if your object has the right type of data in it
# # Example:

# %%
pd_data.head(n=10)
# Out:
#      Height    Weight
# 0  65.78331  112.9925
# 1  71.51521  136.4873
# 2  69.39874  153.0269
# 3  68.21660  142.3354
# 4  67.78781  144.2971
# 5  68.69784  123.3024
# 6  69.80204  141.4947
# 7  70.01472  136.4623
# 8  67.90265  112.3723
# 9  66.78236  120.6672

# %%
# same as above, from the end of the file 
pd_data.tail(n=10)
# Out:
#          Height    Weight
# 24990  69.97767  125.3672
# 24991  71.91656  128.2840
# 24992  70.96218  146.1936
# 24993  66.19462  118.7974
# 24994  67.21126  127.6603
# 24995  69.50215  118.0312
# 24996  64.54826  120.1932
# 24997  64.69855  118.2655
# 24998  67.52918  132.2682
# 24999  68.87761  124.8742

# %% [markdown]
# # info
# Prints a concise summary of a DataFrame
# # Example

# %%
pd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  25000 non-null  float64
#  1   Weight  25000 non-null  float64
# dtypes: float64(2)
# memory usage: 390.8 KB

# %% [markdown]
#  # Shape
#  Returns a tuple representing the dimensionality of the DataFrame
#  # Example

# %%
pd_data.shape
# Out:
# (25000, 2)

# %%
pd_data.sum()  # sum of each column
# Out:
# Height    1.699828e+06
# Weight    3.176986e+06
# dtype: float64

# %%
pd_data.mean() # Average of each column
# Out:
# Height     67.993114
# Weight    127.079421
# dtype: float64

# %%
pd_data.median() # Median of each column
# Out:
# Height     67.99570
# Weight    127.15775
# dtype: float64

# %%
pd_data.var() # Varianve of each column
# Out:
# Height      3.616382
# Weight    135.976532
# dtype: float64

# %%
pd_data.std() # Standard deviation of each column
# Out:
# Height     1.901679
# Weight    11.660898
# dtype: float64

# %%
pd_data[['Height']].std()  # Standard deviation of column 'Height'
# Out:
# Height    1.901679
# dtype: float64

# %%
pd_data[['Height','Weight']].std()  # Standard deviation of two columns
# Out:
# Height     1.901679
# Weight    11.660898
# dtype: float64

# %% [markdown]
# # quantile
# Return values at the given quantile over requested axis.
# # Example

# %%
pd_data.quantile([0.1, 0.9])
# Out:
#         Height     Weight
# 0.1  65.543847  112.10984
# 0.9  70.445094  141.91209

# %%
pd_data[["Height"]].quantile([0.1, 0.9])
# Out:
#         Height
# 0.1  65.543847
# 0.9  70.445094

# %%
pd_data[["Height"]].kurtosis()
# Out:
# Height   -0.035159
# dtype: float64

# %%
pd_data[["Height"]].values
# Out:
# array([[65.78331],
#        [71.51521],
#        [69.39874],
#        ...,
#        [64.69855],
#        [67.52918],
#        [68.87761]])

# %% [markdown]
# # describe
# Generates descriptive statistics of DataFrame columns
# # Example

# %%
pd_data.describe()
# Out:
#              Height        Weight
# count  25000.000000  25000.000000
# mean      67.993114    127.079421
# std        1.901679     11.660898
# min       60.278360     78.014760
# 25%       66.704397    119.308675
# 50%       67.995700    127.157750
# 75%       69.272958    134.892850
# max       75.152800    170.924000

# %%
pd_data.hist(bins=20, figsize=(15,15))  # plot all histograms
# Out:
# array([[<AxesSubplot:title={'center':'Height'}>,
#         <AxesSubplot:title={'center':'Weight'}>]], dtype=object)

# %%
pd_data[['Height']].hist(bins=50, figsize=(10,10))    # plot a histogram of the feature, you can change the size and the histogram's bin
# Out:
# array([[<AxesSubplot:title={'center':'Height'}>]], dtype=object)

# %%
pd_data['Weight'].hist(bins=50, figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
pd_data['Height'].kurtosis()
# Out:
# -0.03515940944584184

# %%
pd_data['Height'].skew()
# Out:
# -0.00565797936693913

# %% [markdown]
# # The second example
# https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Load your csv data:
pd_house= pd.read_csv('Boston_Housing_org.csv')

print('loading data, Done!')
# Out:
# loading data, Done!

# %%
pd_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0.1        20640 non-null  int64
#  1   Unnamed: 0          20640 non-null  int64
#  2   longitude           20640 non-null  float64
#  3   latitude            20640 non-null  float64
#  4   housing_median_age  20640 non-null  float64
#  5   total_rooms         20640 non-null  float64
#  6   total_bedrooms      20640 non-null  float64
#  7   population          20640 non-null  float64
#  8   households          20640 non-null  float64
#  9   median_income       20640 non-null  float64
#  10  median_house_value  20640 non-null  float64
#  11  ocean_proximity     20640 non-null  object
# dtypes: float64(9), int64(2), object(1)
# memory usage: 1.9+ MB

# %%
pd_house
# Out:
#        Unnamed: 0.1  Unnamed: 0  longitude  latitude  housing_median_age  \
# 0                 0           0    -122.23     37.88                41.0
# 1                 1           1    -122.22     37.86                21.0
# 2                 2           2    -122.24     37.85                52.0
# 3                 3           3    -122.25     37.85                52.0
# 4                 4           4    -122.25     37.85                52.0
# ...             ...         ...        ...       ...                 ...
# 20635         20635       20635    -121.09     39.48                25.0
# 20636         20636       20636    -121.21     39.49                18.0
# 20637         20637       20637    -121.22     39.43                17.0
# 20638         20638       20638    -121.32     39.43                18.0
# 20639         20639       20639    -121.24     39.37                16.0
#
#        total_rooms  total_bedrooms  population  households  median_income  \
# ...

# %% [markdown]
# # Load data with NaNs and use the followoing functions to fill them:
#
# HW_data_NaN.fillna(HW_data_NaN.median())

# %%
# Read file 'Height_Weight_NaN.csv' as HW_data_NaN
HW_data_NaN= pd.read_csv('Height_Weight_NaN.csv')
print('the file loaded')
# Out:
# the file loaded

# %%
# see the table
HW_data_NaN
# Out:
#          Height    Weight
# 0      65.78331  112.9925
# 1      71.51521       NaN
# 2      69.39874  153.0269
# 3      68.21660  142.3354
# 4           NaN  144.2971
# ...         ...       ...
# 24995  69.50215  118.0312
# 24996  64.54826  120.1932
# 24997  64.69855  118.2655
# 24998  67.52918  132.2682
# 24999  68.87761  124.8742
#
# [25000 rows x 2 columns]

# %%
# see information of the file
HW_data_NaN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  24891 non-null  float64
#  1   Weight  24858 non-null  float64
# dtypes: float64(2)
# memory usage: 390.8 KB

# %%
# a new name for the corrected file
#use  'ffill' if you want to propagate the last valid observation forward 

HW_data_NaN_fillmed= HW_data_NaN.fillna(HW_data_NaN.median())

# %%
HW_data_NaN_fillmed.to_csv('HW_data_NaN_fillmed.csv',index=False)
print ('The new file was saved')
# Out:
# The new file was saved

# %%
# a new name for the corrected file
HW_data_NaN_drop= HW_data_NaN.dropna()

# %%
HW_data_NaN_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24751 entries, 0 to 24999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  24751 non-null  float64
#  1   Weight  24751 non-null  float64
# dtypes: float64(2)
# memory usage: 580.1 KB

# %%
type(HW_data_NaN_drop)
# Out:
# pandas.core.frame.DataFrame

# %%
(HW_data_NaN_drop.values).shape
# Out:
# (24751, 2)

# %%
HW_values = HW_data_NaN_drop.values
type(HW_values)
# Out:
# numpy.ndarray

# %%
HW_values.shape
# Out:
# (24751, 2)

# %% [markdown]
# # >>>>>> explor the cancer data set with Pandas
